# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import altair as alt
import seaborn as sns

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /Users/ariellerabinovich/anaconda3/lib/python3.11/site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /Users/ariellerabinovich/anaconda3/lib/python3.11/site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in /Users/ariellerabinovich/anaconda3/lib/python3.11/site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /Users/ariellerabinovich/anaconda3/lib/python3.11/site-packages (from wordcloud) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ariellerabinovich/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/ariellerabinovich/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ariellerabinovich/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ariellerabinovich/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/ariellerabinovich/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ariellerabinovich/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ariellerabinovich/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/ariellerabinovich/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('spotify.csv')

# %%
df.head()
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.624   0.433    -9.572       0.0467        0.8370
# 1         0.614   0.785    -8.224       0.0668        0.5490
# 2         0.901   0.697    -3.439       0.2800        0.1450
# 3         0.559   0.345   -13.496       0.0459        0.0576
# 4         0.615   0.550   -13.858       0.0349        0.0546
#
#    instrumentalness  liveness  valence    tempo                      id  \
# 0          0.029400     0.113    0.589  124.979  4h5x3XHLVYFJaItKuO2rhy
# 1          0.842000     0.348    0.853  180.036  70jc6VUdHljHN6y2AGkpyC
# 2          0.000000     0.287    0.670   93.941  7KwZNVEaqikRSBSpyhXK2j
# 3          0.000105     0.141    0.458   84.581  3d9DChrdc6BOeFsbrZ3Is0
# 4          0.190000     0.747    0.549   95.488  3xGJuHvSxFJxxYlHj5BIoT
#
#                                     uri  \
# 0  spotify:track:4h5x3XHLVYFJaItKuO2rhy
# 1  spotify:track:70jc6VUdHljHN6y2AGkpyC
# 2  spotify:track:7KwZNVEaqikRSBSpyhXK2j
# 3  spotify:track:3d9DChrdc6BOeFsbrZ3Is0
# 4  spotify:track:3xGJuHvSxFJxxYlHj5BIoT
#
#                                        artist_genres  \
# 0                              ['pop', 'r&b', 'rap']
# 1      ['hip hop', 'ohio hip hop', 'pop rap', 'rap']
# 2  ['east coast hip hop', 'gangster rap', 'hardco...
# 3  ['alternative rock', 'funk metal', 'funk rock'...
# 4  ['album rock', 'art rock', 'classic rock', 'pr...
#
#                                      track_name            artist_name  \
# 0  Ghost in the Machine (feat. Phoebe Bridgers)                    SZA
# 1                                  Mojo So Dope               Kid Cudi
# 2                     Hypnotize - 2014 Remaster   The Notorious B.I.G.
# 3                              Under the Bridge  Red Hot Chili Peppers
# 4                                    Young Lust             Pink Floyd
#
#                                                album  user
# 0                                                SOS  Mimi
# 1  Man On The Moon II: The Legend Of Mr. Rager (E...  Mimi
# 2         Life After Death (2014 Remastered Edition)  Mimi
# 3             Blood Sugar Sex Magik (Deluxe Edition)  Mimi
# 4                                           The Wall  Mimi

# %%
import ast
from wordcloud import WordCloud, STOPWORDS

# %%
mimi_genre = []
for index, row in df.iterrows():
    if row['user']=='Mimi':
        (mimi_genre.append(ast.literal_eval(row['artist_genres'])))

# %%
mimi_words = [i for x in mimi_genre for i in x]

# %%
comment_words = ''
stopwords = set(STOPWORDS)

# %%
for i in range(len(mimi_words)):
        mimi_words[i] = mimi_words[i].lower()
     
comment_words += " ".join(mimi_words)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10,
                colormap = 'twilight').generate(comment_words)
 
# plot the WordCloud image                       
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
plt.savefig('mimi_cloud.jpg')

# %%
ari_genre = []
for index, row in df.iterrows():
    if row['user']=='Arielle':
        (ari_genre.append(ast.literal_eval(row['artist_genres'])))

# %%
ari_words = [i for x in ari_genre for i in x]

# %%
comment_words2 = ''
stopwords = set(STOPWORDS)

# %%
for i in range(len(ari_words)):
        ari_words[i] = ari_words[i].lower()
     
comment_words2 += " ".join(ari_words)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10,
                colormap = 'summer').generate(comment_words2)
 
# plot the WordCloud image                       
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
plt.savefig('arielle_cloud.jpg')

# %%
justin_genre = []
for index, row in df.iterrows():
    if row['user']=='Justin':
        (justin_genre.append(ast.literal_eval(row['artist_genres'])))

# %%
comment_words3 = ''
stopwords = set(STOPWORDS)

# %%
justin_words = [i for x in justin_genre for i in x]

# %%
for i in range(len(justin_words)):
        justin_words[i] = justin_words[i].lower()
     
comment_words3 += " ".join(justin_words)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10,
                colormap='inferno').generate(comment_words3)
 
# plot the WordCloud image                       
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %% [markdown]
# 	1. Scatter plot showing liveliness vs tempo, colored by users and select/highlight different users (altair)
# tooltip w song name

# %%
df.columns
# Out:
# Index(['danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'id', 'uri',
#        'artist_genres', 'track_name', 'artist_name', 'album', 'user'],
#       dtype='object')

# %%
import altair as alt

# Establishing selection via region
selection = alt.selection_single(fields=['user'])

# Color mapping
color_mapping = {'Arielle': "#67a34f", 'Mimi': '#540b84', 'Justin': '#ea9726'}

# Establishing color change based on selection
color = alt.condition(
    selection,
    alt.Color('user:N', scale=alt.Scale(domain=list(color_mapping.keys()), range=list(color_mapping.values())), legend=None),
    alt.value('lightgrey')
)

# Declaring chart
chart1 = alt.Chart(df).mark_circle().encode(
    alt.X('danceability:Q', title='Danceability'),
    alt.Y('tempo:Q', title='Tempo'),
    
    # Declaring tooltip
    alt.Tooltip(['user:N', 'track_name:N', 'tempo:Q', 'danceability:Q', 'artist_name:N']),
    
    # Declaring color
    color=color
).add_selection(selection).properties(
    height=200,
    width=500,
    title='Danceability vs Tempo'
)

# Creating legend
legend = alt.Chart(df).mark_circle().encode(
    y=alt.Y('user:N', title='User'),
    color=alt.Color('user:N', scale=alt.Scale(domain=list(color_mapping.keys()), range=list(color_mapping.values())), legend=None)
).add_selection(selection)

# Combining chart and legend
interact_1 = (chart1 | legend)
# Out:
# /Users/ariellerabinovich/anaconda3/lib/python3.11/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_single' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /Users/ariellerabinovich/anaconda3/lib/python3.11/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)

# %%
interact_1
# Out:
# alt.HConcatChart(...)

# %%
interact_1.save('interact1.html')

# %% [markdown]
# One scatter plot showing liveness vs acousticness then when you highlight a section, selects on scatter plot below showing danceability and acousticness
# 		a.  tooltip w song name (altair)

# %%
import altair as alt

# Define colors and color scale
colors = ["#540b84", "#540b84", "#67a34f"]
color_scale = alt.Scale(domain=df['user'].unique().tolist(), range=colors)

# Establishing selection via region
selection = alt.selection_single(fields=['user'], name='User', empty='all')

# Color mapping
color_mapping = {'Arielle': "#67a34f", 'Mimi': '#540b84', 'Justin': '#ea9726'}

# Establishing color change based on selection
color = alt.condition(
    selection,
    alt.Color('user:N', scale=color_scale, legend=None),
    alt.value('lightgrey')
)

# Establishing brush for interactivity
brush = alt.selection_interval(encodings=['x'])

# Chart 2: Liveliness vs Acousticness
chart2 = alt.Chart(df).mark_circle().encode(
    alt.X('acousticness:Q', title='Acousticness'),
    alt.Y('liveness:Q', title='Liveliness'),
    alt.Tooltip(['user:N', 'track_name:N', 'liveness:Q', 'acousticness:Q', 'artist_name:N']),
    color=color
).add_selection(selection).properties(
    height=200,
    width=500,
    title='Liveliness vs Acousticness'
)

# Legend
legend = alt.Chart(df).mark_circle().encode(
    y=alt.Y('user:N'),
    color=alt.Color('user:N', scale=alt.Scale(domain=list(color_mapping.keys()), range=list(color_mapping.values())), legend=None)
).add_selection(selection)

# Chart 3: Acousticness vs Danceability
chart3 = alt.Chart(df).mark_circle().encode(
    alt.X('acousticness:Q', title='Acousticness').scale(domain=brush),
    alt.Y('danceability:Q', title='Danceability'),
    alt.Tooltip(['user:N', 'track_name:N', 'danceability:Q', 'acousticness:Q', 'artist_name:N']),
    color=color
).add_selection(brush).properties(
    height=200,
    width=500,
    title='Acousticness vs Danceability'
)

# Combining charts
chart4 = (chart2 | legend) & chart3
chart4
# Out:
# alt.VConcatChart(...)

# %%
chart4.save('interact_2.html')
